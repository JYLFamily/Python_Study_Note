# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.preprocessing import *
from sklearn.feature_selection import *

# %% [markdown]
# ## 数据集导入

# %%
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.DataFrame(iris.target)

# %% [markdown]
# ### Filter

# %% [markdown]
# #### 方差选择法

# %%
# 特征方差小于 0.001 的将会被剔除
selector = VarianceThreshold(threshold=0.001).fit(X)
X = selector.transform(X)
pd.DataFrame(X).head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.0</td>
#       <td>3.6</td>
#       <td>1.4</td>
#       <td>0.2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# %matplotlib inline

pd.DataFrame(X).corr()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.000000</td>
#       <td>-0.109369</td>
#       <td>0.871754</td>
#       <td>0.817954</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.109369</td>
#       <td>1.000000</td>
#       <td>-0.420516</td>
#       <td>-0.356544</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.871754</td>
#       <td>-0.420516</td>
#       <td>1.000000</td>
#       <td>0.962757</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.817954</td>
#       <td>-0.356544</td>
#       <td>0.962757</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## And So On
